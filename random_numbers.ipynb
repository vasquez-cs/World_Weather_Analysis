# %%
# Import the random module.
import random

# %%
random.randint(-90, 90)
# Out:
# 9

# %%
random.random()
# Out:
# 0.7985904364241143

# %%
#Assign the variable x to 1.
#Initialize an empty list, latitudes.
#We create a while loop where we generate a random latitude and add it to the list.
#After the random latitude is added to the list we add one to the variable "x".
#The while loop condition is checked again and will continue to run as long as x is less than 11.

x = 1
latitudes = []
while x < 11:
    random_lat = random.randint(-90, 89) + random.random()
    latitudes.append(random_lat)
    x += 1

# %%
print(latitudes)
# Out:
# [20.91723114691547, -26.742588505436512, 69.15236881700761, -46.626604345411586, -24.877084486046734, -0.18510375674146873, -20.961168871004972, 15.497507985806683, 46.69954338501922, -68.92019615350185]

# %%
random.randrange(-90,90,step=1)
# Out:
# 77

# %%
random.randrange(-90,90,step=3)
# Out:
# 9

# %%
random.uniform(-90, 90)
# Out:
# -70.10964453600704

# %%
# Import the NumPy module.
import numpy as np

# %%
np.random.uniform(-90.000, 90.000)
#alternate to script above is np.random.uniform(low=-90, high=90)
# Out:
# -15.563878539949926

# %%
np.random.uniform(-90.000, 90.000, size=50)
# Out:
# array([ 50.04957007,  49.46419466, -28.16611529, -77.49804574,
#         10.05373375, -10.10690625,  87.53315695,  19.47770237,
#         47.35975165,  45.546127  ,   1.31945561, -43.44208907,
#         70.36737524,  76.87701149,  -1.75303353,  -3.98701507,
#         37.16366437, -71.80821893, -46.89217874, -16.16751575,
#        -53.16153174, -76.17692838,  70.41189409,  48.62751972,
#        -64.06517366, -62.70284877,  43.29431358,  -0.09702265,
#         -0.14844094,  -9.85271004,   5.35595752,   5.39541907,
#         78.99468994,  66.58186612,  80.72403173,  19.81965758,
#         52.95946436,  37.31182833, -50.51323611,  68.47416667,
#         25.13671094,  50.90323372,  16.75680965,  66.46700393,
#        -32.09201319, -52.92393287, -28.04908612,  74.2588734 ,
#        -59.87533779,  45.96198428])

# %%
# Import timeit.
import timeit

# %%
# %timeit np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# 16.2 µs ± 1.01 µs per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 1.82 ms ± 121 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
#SKILL DRILL
#Refactor the code for the while loop with the %timeit magic command and write a for loop that will generate the 1,500 latitudes.


x = 1
latitudes_sk = []
time = %timeit
while x < 1501:
    random_lat = random.randint(-90, 89) + random.random()
    latitudes_sk.append(random_lat)
    x += 1

# %%
print(latitudes_sk, time)
# Out:
# [-56.5919943632822, 41.866170781767764, -86.77716828220049, -79.24961415696143, 8.901258449607166, -63.84445216423026, 47.13038839211565, 12.144061834980965, 21.45952176070814, -27.231572939848693, 27.002266101290285, -45.18461132895865, 30.03026113631254, -57.78419588153467, -75.38305287593603, -79.6275300133644, -81.04515567024703, -86.38804094162506, -38.45383216886669, 8.802076642979769, 8.361837324670972, 85.75698706830171, -65.25439328755306, -78.02538375065514, 42.301907728790695, -61.80904751111728, -41.76700801929094, -79.60319204