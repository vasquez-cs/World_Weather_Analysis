# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Create 2000 sets of random latitude and longitude combinations per module 6 instructions.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the print() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# -23.974791869897402 13.90231787071005
# -56.41664877050439 -71.85507530460771
# 47.22919561805816 -125.60506426082347
# -51.30154081900833 -30.028001163513693
# -31.611410167857656 -135.26618019935847
# 29.942131742829716 -130.02057958557972
# 33.32315609706417 65.93740281183153
# 72.76155367283226 37.600374400893486
# 14.617056508140863 30.596639839481668
# 61.00065211033623 -103.45393738449383
# 14.637523214577612 148.17640143477524
# -58.41457334631019 -179.84926008377093
# -17.755713165011016 -105.34680528861877
# 48.0084120143388 -71.66405691926812
# -28.53206946962844 -65.89083103628715
# 3.7045855934428857 -1.4147209213238625
# -23.20924255768179 -63.24925269309614
# 30.390335849691553 -111.09436773759728
# -17.53601038492225 13.93379906654809
# 73.5686356417821 -86.14982382840529
# -0.5411469670269611 24.646633771543833
# 21.294877629520883 -33.77009065807806
# -10.055296420242371 -76.59316825642321
# 14.424260754240805 -80.93221475326959
# ...

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 758

# %%
cities
# Out:
# ['walvis bay',
#  'punta arenas',
#  'ucluelet',
#  'cidreira',
#  'rikitea',
#  'pacific grove',
#  'uruzgan',
#  'tumannyy',
#  'bara',
#  'la ronge',
#  'airai',
#  'vaini',
#  'puerto ayora',
#  'hebertville',
#  'catamarca',
#  'takoradi',
#  'tartagal',
#  'santa ana',
#  'opuwo',
#  'qaanaaq',
#  'kisangani',
#  'ponta do sol',
#  'san miguel de cauri',
#  'san andres',
#  'aklavik',
#  'hobart',
#  'alice springs',
#  'lompoc',
#  'port elizabeth',
#  'tomatlan',
#  'hilo',
#  'pisco',
#  'maciel',
#  'kavieng',
#  'mataura',
#  'cayenne',
#  'chiman',
#  'port augusta',
#  'cape town',
#  'manokwari',
#  'sorrento',
#  'xai-xai',
#  'provideniya',
#  'hasaki',
#  'faanui',
#  'zambezi',
#  'le vauclin',
#  'tuatapere',
#  'busselton',
#  'nelson bay',
#  'srednekolymsk',
#  'loandjili',
#  'belushya guba',
#  'gamba',
#  'agadir',
#  'mys shmidta',
#  'barrow',
#  'margate',
#  'bathsheba',
#  'jibuti',
#  'ushuaia',
#  'kodiak',
#  'bredasdorp',
#  'leningradskiy',
# ...

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key + "&lang={en}"
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60e3390eacf7d689fb8fed220594f948&lang={en}

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        # this was a pain. The city description wasn't working, as all my cities were coming up as "City not found"
        # after extensive googling, i found this: https://stackoverflow.com/questions/71785453/json-path-starting-with-0#:~:text=0%20is%20index%20of%20array,do%20readableData.length%3B%20%2F%2F%201
        
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,                          
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | walvis bay
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | ucluelet
# Processing Record 4 of Set 1 | cidreira
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | pacific grove
# Processing Record 7 of Set 1 | uruzgan
# Processing Record 8 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 1 | bara
# Processing Record 10 of Set 1 | la ronge
# Processing Record 11 of Set 1 | airai
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | puerto ayora
# Processing Record 14 of Set 1 | hebertville
# City not found. Skipping...
# Processing Record 15 of Set 1 | catamarca
# Processing Record 16 of Set 1 | takoradi
# Processing Record 17 of Set 1 | tartagal
# Processing Record 18 of Set 1 | santa ana
# Processing Record 19 of Set 1 | opuwo
# Processing Record 20 of Set 1 | qaanaaq
# ...

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Walvis Bay      NA -22.9575   14.5053     51.10        87           0
# 1   Punta Arenas      CL -53.1500  -70.9167     30.31        86          40
# 2       Ucluelet      CA  48.9329 -125.5528     58.08        91           6
# 3       Cidreira      BR -30.1811  -50.2056     60.33        96           5
# 4        Rikitea      PF -23.1203 -134.9692     73.51        77           0
# 5  Pacific Grove      US  36.6177 -121.9166     58.24        94         100
# 6        Uruzgan      AF  32.8333   66.0000     93.16        10           0
# 7           Bara      NG  10.3744   10.7288     71.73        90          99
# 8       La Ronge      CA  55.1001 -105.2842     66.45        52          20
# 9          Airai      TL  -8.9266  125.4092     68.52        64          75
#
#    Wind Speed        Description                 Date
# 0        6.91          clear sky  2022-07-21 05:37:32
# ...

# %%
# Create the output file (CSV).
output_data_file = "C://Users/Carlos/BootCamp/World_Weather_Analysis/Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
